# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# 도서관 정보

# %%
df = pd.read_csv('data/NL_CD_LIBRARY_202211.csv')

# %%
df
# Out:
#       LBRRY_CD      LBRRY_NM               LBRRY_ADDR   LBRRY_LA    LBRRY_LO  \
# 0         1500     포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26  37.905303  127.206376
# 1         1501     포천시립소흘도서관   경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2         1502     포천시립일동도서관     경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3         1503  포천시립영중꿈나무도서관      경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4         1504     포천시립영북도서관       경기도 포천시 영북면 운천안길 3  38.087682  127.274170
# ...        ...           ...                      ...        ...         ...
# 1492      2657       원동작은도서관    경상남도 양산시 원동면 원동로 1598  35.370255  128.920549
# 1493      2624     물구나무작은도서관         경상남도 양산시 서창로 194  35.416340  129.173441
# 1494      6704      제천기적의도서관      충청북도 제천시 용두천로38길 30  37.155205  128.220023
# 1495     33600       남원시립도서관         전라북도 남원시 광한북로 54  35.407697  127.380214
# 1496     33601  남원시어린이청소년도서관         전라북도 남원시 역재3길 12  35.419891  127.399799
#
# ...

# %%
df = df[['LBRRY_NM','LBRRY_ADDR','LBRRY_LA','LBRRY_LO','ONE_AREA_NM','TWO_AREA_NM','LBRRY_TY_NM']]

# %%
df
# Out:
#           LBRRY_NM               LBRRY_ADDR   LBRRY_LA    LBRRY_LO  \
# 0        포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26  37.905303  127.206376
# 1        포천시립소흘도서관   경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2        포천시립일동도서관     경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3     포천시립영중꿈나무도서관      경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4        포천시립영북도서관       경기도 포천시 영북면 운천안길 3  38.087682  127.274170
# ...            ...                      ...        ...         ...
# 1492       원동작은도서관    경상남도 양산시 원동면 원동로 1598  35.370255  128.920549
# 1493     물구나무작은도서관         경상남도 양산시 서창로 194  35.416340  129.173441
# 1494      제천기적의도서관      충청북도 제천시 용두천로38길 30  37.155205  128.220023
# 1495       남원시립도서관         전라북도 남원시 광한북로 54  35.407697  127.380214
# 1496  남원시어린이청소년도서관         전라북도 남원시 역재3길 12  35.419891  127.399799
#
#      ONE_AREA_NM TWO_AREA_NM LBRRY_TY_NM
# 0            경기도         포천시          공공
# 1            경기도         포천시          공공
# ...

# %%
df['ONE_AREA_NM'].unique()
# Out:
# array(['경기도', '경상남도', '강원도', '경상북도', '인천광역시', '서울특별시', '전라남도', '광주광역시',
#        '전라북도', '충청남도', '세종특별자치시', '충청북도', '제주특별자치도', '대전광역시', '울산광역시',
#        '부산광역시', '대구광역시'], dtype=object)

# %%
df = df.rename(columns={'LBRRY_NM' : '도서관명', 'LBRRY_ADDR' : '주소', 'LBRRY_LA' : 'lat', 'LBRRY_LO' : 'lon',
                        'ONE_AREA_NM' : '지역', 'TWO_AREA_NM' : '세부지역', 'LBRRY_TY_NM' : '분류'})

# %%
df
# Out:
#               도서관명                       주소        lat         lon    지역 세부지역  \
# 0        포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26  37.905303  127.206376   경기도  포천시
# 1        포천시립소흘도서관   경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534   경기도  포천시
# 2        포천시립일동도서관     경기도 포천시 일동면 화동로 1021  37.954936  127.315456   경기도  포천시
# 3     포천시립영중꿈나무도서관      경기도 포천시 영중면 양문로 151  38.005629  127.245302   경기도  포천시
# 4        포천시립영북도서관       경기도 포천시 영북면 운천안길 3  38.087682  127.274170   경기도  포천시
# ...            ...                      ...        ...         ...   ...  ...
# 1492       원동작은도서관    경상남도 양산시 원동면 원동로 1598  35.370255  128.920549  경상남도  양산시
# 1493     물구나무작은도서관         경상남도 양산시 서창로 194  35.416340  129.173441  경상남도  양산시
# 1494      제천기적의도서관      충청북도 제천시 용두천로38길 30  37.155205  128.220023  충청북도  제천시
# 1495       남원시립도서관         전라북도 남원시 광한북로 54  35.407697  127.380214  전라북도  남원시
# 1496  남원시어린이청소년도서관         전라북도 남원시 역재3길 12  35.419891  127.399799  전라북도  남원시
#
#       분류
# 0     공공
# 1     공공
# ...

# %%
df = df.dropna()

# %%
# 지역별 도서관 정보

# %%
df['지역'].value_counts()
# Out:
# 경기도        381
# 서울특별시      331
# 경상남도       113
# 경상북도       104
# 대구광역시       90
# 충청남도        70
# 전라북도        63
# 전라남도        52
# 부산광역시       51
# 강원도         47
# 충청북도        45
# 울산광역시       35
# 인천광역시       33
# 대전광역시       26
# 광주광역시       24
# 세종특별자치시     16
# 제주특별자치도     15
# Name: 지역, dtype: int64

# %%
df_count = df['지역'].value_counts()

# %%
df_count = df_count.to_frame().reset_index()

# %%
df_count
# Out:
#       index   지역
# 0       경기도  381
# 1     서울특별시  331
# 2      경상남도  113
# 3      경상북도  104
# 4     대구광역시   90
# 5      충청남도   70
# 6      전라북도   63
# 7      전라남도   52
# 8     부산광역시   51
# 9       강원도   47
# 10     충청북도   45
# 11    울산광역시   35
# 12    인천광역시   33
# 13    대전광역시   26
# 14    광주광역시   24
# 15  세종특별자치시   16
# 16  제주특별자치도   15

# %%
df['세부지역'].value_counts()
# Out:
# 김해시    48
# 동구     43
# 북구     41
# 부천시    37
# 강남구    33
#        ..
# 담양군     1
# 의령군     1
# 진도군     1
# 철원군     1
# 하동군     1
# Name: 세부지역, Length: 237, dtype: int64

# %%
# 경기도의 도서관

# %%
df.loc[df['지역'] == '경기도']
# Out:
#                 도서관명                             주소        lat         lon  \
# 0          포천시립중앙도서관        경기도 포천시 신북면 중앙로207번길 26  37.905303  127.206376
# 1          포천시립소흘도서관         경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2          포천시립일동도서관           경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3       포천시립영중꿈나무도서관            경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4          포천시립영북도서관             경기도 포천시 영북면 운천안길 3  38.087682  127.274170
# ...              ...                            ...        ...         ...
# 1468      오산시 소리울도서관            경기도 오산시 경기대로 102-25  37.133915  127.073237
# 1469          무지개도서관  경기도 오산시 청호로 23-22, 105동 놀이터 안  37.129890  127.082246
# 1470       고현초꿈키움도서관               경기도 오산시 남부대로 459  37.133638  127.085430
# 1471  세교쌍용예가 시민개방도서관           경기도 오산시 내삼미로 110, 2층  37.164568  127.067953
# 1472    화성시립서연이음터도서관            경기도 화성시 동탄순환대로8길 57  37.209803  127.058794
#
#        지역 세부지역  분류
# 0     경기도  포천시  공공
# 1     경기도  포천시  공공
# ...

# %%
# 경기도 포천시 도서관
df.loc[ (df['지역'] == '경기도') & (df['세부지역'] == '포천시') ]
# Out:
#               도서관명                       주소        lat         lon   지역 세부지역  \
# 0        포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26  37.905303  127.206376  경기도  포천시
# 1        포천시립소흘도서관   경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534  경기도  포천시
# 2        포천시립일동도서관     경기도 포천시 일동면 화동로 1021  37.954936  127.315456  경기도  포천시
# 3     포천시립영중꿈나무도서관      경기도 포천시 영중면 양문로 151  38.005629  127.245302  경기도  포천시
# 4        포천시립영북도서관       경기도 포천시 영북면 운천안길 3  38.087682  127.274170  경기도  포천시
# 5        포천시립가산도서관      경기도 포천시 가산면 선마로 223  37.848403  127.186356  경기도  포천시
# 1255     포천시립선단도서관     경기도 포천시 삼육사로2186번길 7  37.853691  127.157752  경기도  포천시
# 1358     경기포천교육도서관         경기도 포천시 중앙로 92-6  37.894479  127.201809  경기도  포천시
#
#       분류
# 0     공공
# 1     공공
# 2     공공
# 3     공공
# 4     공공
# 5     공공
# 1255  공공
# 1358  공공

# %%
# 서울 노원구 도서관
df.loc[ (df['지역'] == '서울특별시') & (df['세부지역'] == '노원구') ]
# Out:
#                  도서관명                        주소        lat         lon     지역  \
# 169   서울특별시교육청노원평생학습관      서울특별시 노원구 동일로204길 13  37.639396  127.067748  서울특별시
# 855           노원중앙도서관       서울특별시 노원구 노원로34길 43  37.661061  127.064997  서울특별시
# 856          노원어린이도서관       서울특별시 노원구 한글비석로 346  37.658008  127.076284  서울특별시
# 857             월계도서관         서울특별시 노원구 월계로 319  37.628605  127.056107  서울특별시
# 858             상계도서관      서울특별시 노원구 동일로243길 57  37.678418  127.051850  서울특별시
# 859             불암도서관         서울특별시 노원구 중계로 106  37.645228  127.082568  서울특별시
# 860             화랑도서관       서울특별시 노원구 노원로1나길 10  37.621472  127.083021  서울특별시
# 861          하계어린이도서관  서울특별시 노원구 공릉로58가길 13, 2층  37.636075  127.072949  서울특별시
# 1432         월계어린이도서관        서울특별시 노원구 월계로42길 9  37.621681  127.053177  서울특별시
# 1433          공릉행복도서관      서울특별시 노원구 동일로179길 22  37.622310  127.072753  서울특별시
# 1434        한내지혜의숲도서관          서울특별시 노원구 마들로 86  37.621734  127.067641  서울특별시
# ...

# %%
# 경기도 포천시의 공공 도서관
df.loc[ (df['지역'] == '경기도') & (df['세부지역'] == '포천시') & (df['분류'] == '공공') ]
# Out:
#               도서관명                       주소        lat         lon   지역 세부지역  \
# 0        포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26  37.905303  127.206376  경기도  포천시
# 1        포천시립소흘도서관   경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534  경기도  포천시
# 2        포천시립일동도서관     경기도 포천시 일동면 화동로 1021  37.954936  127.315456  경기도  포천시
# 3     포천시립영중꿈나무도서관      경기도 포천시 영중면 양문로 151  38.005629  127.245302  경기도  포천시
# 4        포천시립영북도서관       경기도 포천시 영북면 운천안길 3  38.087682  127.274170  경기도  포천시
# 5        포천시립가산도서관      경기도 포천시 가산면 선마로 223  37.848403  127.186356  경기도  포천시
# 1255     포천시립선단도서관     경기도 포천시 삼육사로2186번길 7  37.853691  127.157752  경기도  포천시
# 1358     경기포천교육도서관         경기도 포천시 중앙로 92-6  37.894479  127.201809  경기도  포천시
#
#       분류
# 0     공공
# 1     공공
# 2     공공
# 3     공공
# 4     공공
# 5     공공
# 1255  공공
# 1358  공공

# %%
# 해당 검색결과에 도서관명으로 추가 검색
df.loc[ (df['지역'] == '경기도') & (df['세부지역'] == '포천시') & df['도서관명'].str.contains('시립') ]
# Out:
#               도서관명                       주소        lat         lon   지역 세부지역  \
# 0        포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26  37.905303  127.206376  경기도  포천시
# 1        포천시립소흘도서관   경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534  경기도  포천시
# 2        포천시립일동도서관     경기도 포천시 일동면 화동로 1021  37.954936  127.315456  경기도  포천시
# 3     포천시립영중꿈나무도서관      경기도 포천시 영중면 양문로 151  38.005629  127.245302  경기도  포천시
# 4        포천시립영북도서관       경기도 포천시 영북면 운천안길 3  38.087682  127.274170  경기도  포천시
# 5        포천시립가산도서관      경기도 포천시 가산면 선마로 223  37.848403  127.186356  경기도  포천시
# 1255     포천시립선단도서관     경기도 포천시 삼육사로2186번길 7  37.853691  127.157752  경기도  포천시
#
#       분류
# 0     공공
# 1     공공
# 2     공공
# 3     공공
# 4     공공
# 5     공공
# 1255  공공

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1497 entries, 0 to 1496
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LBRRY_NM     1497 non-null   object
#  1   LBRRY_ADDR   1496 non-null   object
#  2   lat          1496 non-null   float64
#  3   lon          1496 non-null   float64
#  4   ONE_AREA_NM  1497 non-null   object
#  5   TWO_AREA_NM  1497 non-null   object
#  6   LBRRY_TY_NM  1497 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 82.0+ KB

# %%
df.to_csv('LIBRARY_202211.csv')

# %%
newdf = pd.read_csv('LIBRARY_202211.csv',index_col=0)

# %%
newdf
# Out:
#           LBRRY_NM               LBRRY_ADDR        lat         lon  \
# 0        포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26  37.905303  127.206376
# 1        포천시립소흘도서관   경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2        포천시립일동도서관     경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3     포천시립영중꿈나무도서관      경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4        포천시립영북도서관       경기도 포천시 영북면 운천안길 3  38.087682  127.274170
# ...            ...                      ...        ...         ...
# 1492       원동작은도서관    경상남도 양산시 원동면 원동로 1598  35.370255  128.920549
# 1493     물구나무작은도서관         경상남도 양산시 서창로 194  35.416340  129.173441
# 1494      제천기적의도서관      충청북도 제천시 용두천로38길 30  37.155205  128.220023
# 1495       남원시립도서관         전라북도 남원시 광한북로 54  35.407697  127.380214
# 1496  남원시어린이청소년도서관         전라북도 남원시 역재3길 12  35.419891  127.399799
#
#      ONE_AREA_NM TWO_AREA_NM LBRRY_TY_NM
# 0            경기도         포천시          공공
# 1            경기도         포천시          공공
# ...

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1497 entries, 0 to 1496
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LBRRY_NM     1497 non-null   object
#  1   LBRRY_ADDR   1496 non-null   object
#  2   lat          1496 non-null   float64
#  3   lon          1496 non-null   float64
#  4   ONE_AREA_NM  1497 non-null   object
#  5   TWO_AREA_NM  1497 non-null   object
#  6   LBRRY_TY_NM  1497 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 93.6+ KB

# %%
df[['LBRRY_TY_NM', 'ONE_AREA_NM', 'LBRRY_NM', 'LBRRY_ADDR']]
# Out:
#      LBRRY_TY_NM ONE_AREA_NM      LBRRY_NM               LBRRY_ADDR
# 0             공공         경기도     포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26
# 1             공공         경기도     포천시립소흘도서관   경기도 포천시 소흘읍 송우로 101-29
# 2             공공         경기도     포천시립일동도서관     경기도 포천시 일동면 화동로 1021
# 3             공공         경기도  포천시립영중꿈나무도서관      경기도 포천시 영중면 양문로 151
# 4             공공         경기도     포천시립영북도서관       경기도 포천시 영북면 운천안길 3
# ...          ...         ...           ...                      ...
# 1492          작은        경상남도       원동작은도서관    경상남도 양산시 원동면 원동로 1598
# 1493          작은        경상남도     물구나무작은도서관         경상남도 양산시 서창로 194
# 1494          공공        충청북도      제천기적의도서관      충청북도 제천시 용두천로38길 30
# 1495          공공        전라북도       남원시립도서관         전라북도 남원시 광한북로 54
# 1496          공공        전라북도  남원시어린이청소년도서관         전라북도 남원시 역재3길 12
#
# [1497 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# LBRRY_NM       0
# LBRRY_ADDR     1
# lat            1
# lon            1
# ONE_AREA_NM    0
# TWO_AREA_NM    0
# LBRRY_TY_NM    0
# dtype: int64

# %%
df.dropna()
# Out:
#           LBRRY_NM               LBRRY_ADDR        lat         lon  \
# 0        포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26  37.905303  127.206376
# 1        포천시립소흘도서관   경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2        포천시립일동도서관     경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3     포천시립영중꿈나무도서관      경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4        포천시립영북도서관       경기도 포천시 영북면 운천안길 3  38.087682  127.274170
# ...            ...                      ...        ...         ...
# 1492       원동작은도서관    경상남도 양산시 원동면 원동로 1598  35.370255  128.920549
# 1493     물구나무작은도서관         경상남도 양산시 서창로 194  35.416340  129.173441
# 1494      제천기적의도서관      충청북도 제천시 용두천로38길 30  37.155205  128.220023
# 1495       남원시립도서관         전라북도 남원시 광한북로 54  35.407697  127.380214
# 1496  남원시어린이청소년도서관         전라북도 남원시 역재3길 12  35.419891  127.399799
#
#      ONE_AREA_NM TWO_AREA_NM LBRRY_TY_NM
# 0            경기도         포천시          공공
# 1            경기도         포천시          공공
# ...

# %%
df['lat']
# Out:
# 0       37.905303
# 1       37.829605
# 2       37.954936
# 3       38.005629
# 4       38.087682
#           ...
# 1492    35.370255
# 1493    35.416340
# 1494    37.155205
# 1495    35.407697
# 1496    35.419891
# Name: lat, Length: 1497, dtype: float64

# %%
AREAdf = df.loc[ df['지역'] == '경기도' ]

# %%
AREAdf
# Out:
#                 도서관명                             주소        lat         lon  \
# 0          포천시립중앙도서관        경기도 포천시 신북면 중앙로207번길 26  37.905303  127.206376
# 1          포천시립소흘도서관         경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2          포천시립일동도서관           경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3       포천시립영중꿈나무도서관            경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4          포천시립영북도서관             경기도 포천시 영북면 운천안길 3  38.087682  127.274170
# ...              ...                            ...        ...         ...
# 1468      오산시 소리울도서관            경기도 오산시 경기대로 102-25  37.133915  127.073237
# 1469          무지개도서관  경기도 오산시 청호로 23-22, 105동 놀이터 안  37.129890  127.082246
# 1470       고현초꿈키움도서관               경기도 오산시 남부대로 459  37.133638  127.085430
# 1471  세교쌍용예가 시민개방도서관           경기도 오산시 내삼미로 110, 2층  37.164568  127.067953
# 1472    화성시립서연이음터도서관            경기도 화성시 동탄순환대로8길 57  37.209803  127.058794
#
#        지역 세부지역  분류
# 0     경기도  포천시  공공
# 1     경기도  포천시  공공
# ...

# %%
AREAdf_count = AREAdf['지역'].count()

# %%
AREAdf_count
# Out:
# 381

# %%
area_count = AREAdf['세부지역'].value_counts()

# %%
area_count
# Out:
# 부천시         37
# 고양시 덕양구     19
# 화성시         19
# 평택시         15
# 이천시         15
# 파주시         15
# 안산시 단원구     14
# 남양주시        13
# 안산시 상록구     13
# 안성시         13
# 광주시         12
# 시흥시         12
# 김포시         12
# 오산시         11
# 양주시         10
# 의왕시          9
# 고양시 일산동구     9
# 포천시          8
# 고양시 일산서구     8
# 성남시 분당구      8
# 연천군          7
# 의정부시         7
# 여주시          7
# 용인시 기흥구      7
# 하남시          7
# 수원시 영통구      7
# 용인시 처인구      6
# 안양시 동안구      6
# 광명시          6
# 양평군          6
# 수원시 권선구      6
# 수원시 팔달구      5
# 성남시 수정구      5
# 수원시 장안구      4
# 용인시 수지구      4
# 가평군          4
# 안양시 만안구      4
# 성남시 중원구      3
# 구리시          3
# 동두천시         2
# 과천시          2
# 군포시          1
# Name: 세부지역, dtype: int64

# %%
df_count = area_count.to_frame().reset_index()

# %%
df_count
# Out:
#        index  세부지역
# 0        부천시    37
# 1    고양시 덕양구    19
# 2        화성시    19
# 3        평택시    15
# 4        이천시    15
# 5        파주시    15
# 6    안산시 단원구    14
# 7       남양주시    13
# 8    안산시 상록구    13
# 9        안성시    13
# 10       광주시    12
# 11       시흥시    12
# 12       김포시    12
# 13       오산시    11
# 14       양주시    10
# 15       의왕시     9
# 16  고양시 일산동구     9
# 17       포천시     8
# 18  고양시 일산서구     8
# 19   성남시 분당구     8
# 20       연천군     7
# 21      의정부시     7
# 22       여주시     7
# 23   용인시 기흥구     7
# 24       하남시     7
# 25   수원시 영통구     7
# 26   용인시 처인구     6
# 27   안양시 동안구     6
# 28       광명시     6
# 29       양평군     6
# 30   수원시 권선구     6
# 31   수원시 팔달구     5
# 32   성남시 수정구     5
# 33   수원시 장안구     4
# 34   용인시 수지구     4
# 35       가평군     4
# 36   안양시 만안구     4
# 37   성남시 중원구     3
# 38       구리시     3
# 39      동두천시     2
# 40       과천시     2
# 41       군포시     1
