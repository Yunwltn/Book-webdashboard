# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# 도서관 정보

# %%
df = pd.read_csv('data/NL_CD_LIBRARY_202211.csv')

# %%
df
# Out:
#       LBRRY_CD      LBRRY_NM               LBRRY_ADDR   LBRRY_LA    LBRRY_LO  \
# 0         1500     포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26  37.905303  127.206376
# 1         1501     포천시립소흘도서관   경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2         1502     포천시립일동도서관     경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3         1503  포천시립영중꿈나무도서관      경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4         1504     포천시립영북도서관       경기도 포천시 영북면 운천안길 3  38.087682  127.274170
# ...        ...           ...                      ...        ...         ...
# 1492      2657       원동작은도서관    경상남도 양산시 원동면 원동로 1598  35.370255  128.920549
# 1493      2624     물구나무작은도서관         경상남도 양산시 서창로 194  35.416340  129.173441
# 1494      6704      제천기적의도서관      충청북도 제천시 용두천로38길 30  37.155205  128.220023
# 1495     33600       남원시립도서관         전라북도 남원시 광한북로 54  35.407697  127.380214
# 1496     33601  남원시어린이청소년도서관         전라북도 남원시 역재3길 12  35.419891  127.399799
#
# ...

# %%
df = df[['LBRRY_NM','LBRRY_ADDR','LBRRY_LA','LBRRY_LO','ONE_AREA_NM','TWO_AREA_NM','LBRRY_TY_NM']]

# %%
df
# Out:
#           LBRRY_NM               LBRRY_ADDR   LBRRY_LA    LBRRY_LO  \
# 0        포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26  37.905303  127.206376
# 1        포천시립소흘도서관   경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2        포천시립일동도서관     경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3     포천시립영중꿈나무도서관      경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4        포천시립영북도서관       경기도 포천시 영북면 운천안길 3  38.087682  127.274170
# ...            ...                      ...        ...         ...
# 1492       원동작은도서관    경상남도 양산시 원동면 원동로 1598  35.370255  128.920549
# 1493     물구나무작은도서관         경상남도 양산시 서창로 194  35.416340  129.173441
# 1494      제천기적의도서관      충청북도 제천시 용두천로38길 30  37.155205  128.220023
# 1495       남원시립도서관         전라북도 남원시 광한북로 54  35.407697  127.380214
# 1496  남원시어린이청소년도서관         전라북도 남원시 역재3길 12  35.419891  127.399799
#
#      ONE_AREA_NM TWO_AREA_NM LBRRY_TY_NM
# 0            경기도         포천시          공공
# 1            경기도         포천시          공공
# ...

# %%
df = df.rename(columns={'LBRRY_LA' : 'lat', 'LBRRY_LO' : 'lon'})

# %%
df
# Out:
#           LBRRY_NM               LBRRY_ADDR        lat         lon  \
# 0        포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26  37.905303  127.206376
# 1        포천시립소흘도서관   경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2        포천시립일동도서관     경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3     포천시립영중꿈나무도서관      경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4        포천시립영북도서관       경기도 포천시 영북면 운천안길 3  38.087682  127.274170
# ...            ...                      ...        ...         ...
# 1492       원동작은도서관    경상남도 양산시 원동면 원동로 1598  35.370255  128.920549
# 1493     물구나무작은도서관         경상남도 양산시 서창로 194  35.416340  129.173441
# 1494      제천기적의도서관      충청북도 제천시 용두천로38길 30  37.155205  128.220023
# 1495       남원시립도서관         전라북도 남원시 광한북로 54  35.407697  127.380214
# 1496  남원시어린이청소년도서관         전라북도 남원시 역재3길 12  35.419891  127.399799
#
#      ONE_AREA_NM TWO_AREA_NM LBRRY_TY_NM
# 0            경기도         포천시          공공
# 1            경기도         포천시          공공
# ...

# %%
# 지역별 도서관 정보

# %%
df['ONE_AREA_NM'].value_counts()
# Out:
# 경기도        381
# 서울특별시      332
# 경상남도       113
# 경상북도       104
# 대구광역시       90
# 충청남도        70
# 전라북도        63
# 전라남도        52
# 부산광역시       51
# 강원도         47
# 충청북도        45
# 울산광역시       35
# 인천광역시       33
# 대전광역시       26
# 광주광역시       24
# 세종특별자치시     16
# 제주특별자치도     15
# Name: ONE_AREA_NM, dtype: int64

# %%
df['TWO_AREA_NM'].value_counts()
# Out:
# 김해시    48
# 동구     43
# 북구     41
# 부천시    37
# 강남구    34
#        ..
# 담양군     1
# 의령군     1
# 진도군     1
# 철원군     1
# 하동군     1
# Name: TWO_AREA_NM, Length: 237, dtype: int64

# %%
# 경기도의 도서관

# %%
df.loc[df['ONE_AREA_NM'] == '경기도']
# Out:
#             LBRRY_NM                     LBRRY_ADDR        lat         lon  \
# 0          포천시립중앙도서관        경기도 포천시 신북면 중앙로207번길 26  37.905303  127.206376
# 1          포천시립소흘도서관         경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2          포천시립일동도서관           경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3       포천시립영중꿈나무도서관            경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4          포천시립영북도서관             경기도 포천시 영북면 운천안길 3  38.087682  127.274170
# ...              ...                            ...        ...         ...
# 1468      오산시 소리울도서관            경기도 오산시 경기대로 102-25  37.133915  127.073237
# 1469          무지개도서관  경기도 오산시 청호로 23-22, 105동 놀이터 안  37.129890  127.082246
# 1470       고현초꿈키움도서관               경기도 오산시 남부대로 459  37.133638  127.085430
# 1471  세교쌍용예가 시민개방도서관           경기도 오산시 내삼미로 110, 2층  37.164568  127.067953
# 1472    화성시립서연이음터도서관            경기도 화성시 동탄순환대로8길 57  37.209803  127.058794
#
#      ONE_AREA_NM TWO_AREA_NM LBRRY_TY_NM
# ...

# %%
# 경기도 포천시 도서관
df.loc[ (df['ONE_AREA_NM'] == '경기도') & (df['TWO_AREA_NM'] == '포천시') ]
# Out:
#           LBRRY_NM               LBRRY_ADDR        lat         lon  \
# 0        포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26  37.905303  127.206376
# 1        포천시립소흘도서관   경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2        포천시립일동도서관     경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3     포천시립영중꿈나무도서관      경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4        포천시립영북도서관       경기도 포천시 영북면 운천안길 3  38.087682  127.274170
# 5        포천시립가산도서관      경기도 포천시 가산면 선마로 223  37.848403  127.186356
# 1255     포천시립선단도서관     경기도 포천시 삼육사로2186번길 7  37.853691  127.157752
# 1358     경기포천교육도서관         경기도 포천시 중앙로 92-6  37.894479  127.201809
#
#      ONE_AREA_NM TWO_AREA_NM LBRRY_TY_NM
# 0            경기도         포천시          공공
# 1            경기도         포천시          공공
# 2            경기도         포천시          공공
# 3            경기도         포천시          공공
# 4            경기도         포천시          공공
# 5            경기도         포천시          공공
# 1255         경기도         포천시          공공
# ...

# %%
# 서울 노원구 도서관
df.loc[ (df['ONE_AREA_NM'] == '서울특별시') & (df['TWO_AREA_NM'] == '노원구') ]
# Out:
#              LBRRY_NM                LBRRY_ADDR        lat         lon  \
# 169   서울특별시교육청노원평생학습관      서울특별시 노원구 동일로204길 13  37.639396  127.067748
# 855           노원중앙도서관       서울특별시 노원구 노원로34길 43  37.661061  127.064997
# 856          노원어린이도서관       서울특별시 노원구 한글비석로 346  37.658008  127.076284
# 857             월계도서관         서울특별시 노원구 월계로 319  37.628605  127.056107
# 858             상계도서관      서울특별시 노원구 동일로243길 57  37.678418  127.051850
# 859             불암도서관         서울특별시 노원구 중계로 106  37.645228  127.082568
# 860             화랑도서관       서울특별시 노원구 노원로1나길 10  37.621472  127.083021
# 861          하계어린이도서관  서울특별시 노원구 공릉로58가길 13, 2층  37.636075  127.072949
# 1432         월계어린이도서관        서울특별시 노원구 월계로42길 9  37.621681  127.053177
# 1433          공릉행복도서관      서울특별시 노원구 동일로179길 22  37.622310  127.072753
# 1434        한내지혜의숲도서관          서울특별시 노원구 마들로 86  37.621734  127.067641
# 1435          향기나무도서관     서울특별시 노원구 노원로 331, 1층  37.646499  127.068838
#
#      ONE_AREA_NM TWO_AREA_NM LBRRY_TY_NM
# ...

# %%
# 경기도 포천시의 공공 도서관
df.loc[ (df['ONE_AREA_NM'] == '경기도') & (df['TWO_AREA_NM'] == '포천시') & (df['LBRRY_TY_NM'] == '공공') ]
# Out:
#           LBRRY_NM               LBRRY_ADDR        lat         lon  \
# 0        포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26  37.905303  127.206376
# 1        포천시립소흘도서관   경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2        포천시립일동도서관     경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3     포천시립영중꿈나무도서관      경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4        포천시립영북도서관       경기도 포천시 영북면 운천안길 3  38.087682  127.274170
# 5        포천시립가산도서관      경기도 포천시 가산면 선마로 223  37.848403  127.186356
# 1255     포천시립선단도서관     경기도 포천시 삼육사로2186번길 7  37.853691  127.157752
# 1358     경기포천교육도서관         경기도 포천시 중앙로 92-6  37.894479  127.201809
#
#      ONE_AREA_NM TWO_AREA_NM LBRRY_TY_NM
# 0            경기도         포천시          공공
# 1            경기도         포천시          공공
# 2            경기도         포천시          공공
# 3            경기도         포천시          공공
# 4            경기도         포천시          공공
# 5            경기도         포천시          공공
# 1255         경기도         포천시          공공
# ...

# %%
# 해당 검색결과에 도서관명으로 추가 검색
df.loc[ (df['ONE_AREA_NM'] == '경기도') & (df['TWO_AREA_NM'] == '포천시') & (df['LBRRY_TY_NM'] == '공공') & df['LBRRY_NM'].str.contains('시립') ]
# Out:
#           LBRRY_NM               LBRRY_ADDR        lat         lon  \
# 0        포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26  37.905303  127.206376
# 1        포천시립소흘도서관   경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2        포천시립일동도서관     경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3     포천시립영중꿈나무도서관      경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4        포천시립영북도서관       경기도 포천시 영북면 운천안길 3  38.087682  127.274170
# 5        포천시립가산도서관      경기도 포천시 가산면 선마로 223  37.848403  127.186356
# 1255     포천시립선단도서관     경기도 포천시 삼육사로2186번길 7  37.853691  127.157752
#
#      ONE_AREA_NM TWO_AREA_NM LBRRY_TY_NM
# 0            경기도         포천시          공공
# 1            경기도         포천시          공공
# 2            경기도         포천시          공공
# 3            경기도         포천시          공공
# 4            경기도         포천시          공공
# 5            경기도         포천시          공공
# 1255         경기도         포천시          공공

# %%
df.to_csv('LIBRARY_202211.csv')
