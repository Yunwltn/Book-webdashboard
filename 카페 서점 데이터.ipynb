# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/CAFE_BOOK_STOR_LIST_2021.csv')

# %%
df = df.reset_index()

# %%
df = df.loc[: , ['FCLTY_NM', 'LCLAS_NM', 'ZIP_NO', 'FCLTY_ROAD_NM_ADDR', 'FCLTY_LA', 'FCLTY_LO', 'OPTN_DC', 'ADIT_DC']]

# %%
df
# Out:
#         FCLTY_NM LCLAS_NM   ZIP_NO                   FCLTY_ROAD_NM_ADDR  \
# 0        강릉야행북카페      북카페  25528.0          강원 강릉시 임영로155번길 6 1층 45,47호
# 1     북카페 봄날에 연애      북카페  26417.0                       강원 원주시 옛시청길 20
# 2     북카페 책 있는 숲      북카페  26021.0                   강원 태백시 황지로 28 / 3층
# 3         북카페 뜨락      북카페  24114.0                   강원 화천군 화천읍 산천어길 79
# 4         한낮의 바다     독립서점  25505.0  강원도 강릉시 강릉대로159번안길 12 1층, 서점 한낮의 바다
# ...          ...      ...      ...                                  ...
# 1051         카페북      북카페  30121.0                      세종특별자치시 갈매로 353
# 1052        책방소문      북카페  50133.0                 경상남도 거창군 거창읍 하동1길 62
# 1053        이월서가     독립서점  27812.0               충청북도 진천군 이월면 진안로 583-6
# 1054         책방문     일반서점  27638.0             충청북도 음성군 금왕읍 대금로 1434-10
# 1055      텍스트칼로리     독립서점  34615.0                     대전광역시 동구 철갑3길 13
#
#        FCLTY_LA    FCLTY_LO  \
# 0     37.755074  128.890851
# 1     37.352672  127.944585
# ...

# %%
df = df.rename(columns={'FCLTY_LA' : 'lat', 'FCLTY_LO' : 'lon'})

# %%
df
# Out:
#         FCLTY_NM LCLAS_NM   ZIP_NO                   FCLTY_ROAD_NM_ADDR  \
# 0        강릉야행북카페      북카페  25528.0          강원 강릉시 임영로155번길 6 1층 45,47호
# 1     북카페 봄날에 연애      북카페  26417.0                       강원 원주시 옛시청길 20
# 2     북카페 책 있는 숲      북카페  26021.0                   강원 태백시 황지로 28 / 3층
# 3         북카페 뜨락      북카페  24114.0                   강원 화천군 화천읍 산천어길 79
# 4         한낮의 바다     독립서점  25505.0  강원도 강릉시 강릉대로159번안길 12 1층, 서점 한낮의 바다
# ...          ...      ...      ...                                  ...
# 1051         카페북      북카페  30121.0                      세종특별자치시 갈매로 353
# 1052        책방소문      북카페  50133.0                 경상남도 거창군 거창읍 하동1길 62
# 1053        이월서가     독립서점  27812.0               충청북도 진천군 이월면 진안로 583-6
# 1054         책방문     일반서점  27638.0             충청북도 음성군 금왕읍 대금로 1434-10
# 1055      텍스트칼로리     독립서점  34615.0                     대전광역시 동구 철갑3길 13
#
#             lat         lon  \
# 0     37.755074  128.890851
# 1     37.352672  127.944585
# ...

# %%
df['AREA'] = df['FCLTY_ROAD_NM_ADDR'].str[0:1+1]

# %%
df['FCLTY_ROAD_NM_ADDR'].str[0:1+1]
# Out:
# 0       강원
# 1       강원
# 2       강원
# 3       강원
# 4       강원
#         ..
# 1051    세종
# 1052    경상
# 1053    충청
# 1054    충청
# 1055    대전
# Name: FCLTY_ROAD_NM_ADDR, Length: 1056, dtype: object

# %%
df
# Out:
#         FCLTY_NM LCLAS_NM   ZIP_NO                   FCLTY_ROAD_NM_ADDR  \
# 0        강릉야행북카페      북카페  25528.0          강원 강릉시 임영로155번길 6 1층 45,47호
# 1     북카페 봄날에 연애      북카페  26417.0                       강원 원주시 옛시청길 20
# 2     북카페 책 있는 숲      북카페  26021.0                   강원 태백시 황지로 28 / 3층
# 3         북카페 뜨락      북카페  24114.0                   강원 화천군 화천읍 산천어길 79
# 4         한낮의 바다     독립서점  25505.0  강원도 강릉시 강릉대로159번안길 12 1층, 서점 한낮의 바다
# ...          ...      ...      ...                                  ...
# 1051         카페북      북카페  30121.0                      세종특별자치시 갈매로 353
# 1052        책방소문      북카페  50133.0                 경상남도 거창군 거창읍 하동1길 62
# 1053        이월서가     독립서점  27812.0               충청북도 진천군 이월면 진안로 583-6
# 1054         책방문     일반서점  27638.0             충청북도 음성군 금왕읍 대금로 1434-10
# 1055      텍스트칼로리     독립서점  34615.0                     대전광역시 동구 철갑3길 13
#
#             lat         lon  \
# 0     37.755074  128.890851
# 1     37.352672  127.944585
# ...

# %%
df.describe()
# Out:
#             ZIP_NO          lat          lon
# count   1055.00000  1056.000000  1056.000000
# mean   24106.94218    36.756378   127.385545
# std    19530.80550     1.159874     0.825826
# min     1043.00000    33.231553   126.228065
# 25%     6032.50000    35.872864   126.903863
# 50%    18435.00000    37.450787   127.031652
# 75%    41652.50000    37.558485   127.479723
# max    63643.00000    38.211365   129.442013

# %%
df.isna().sum()
# Out:
# FCLTY_NM               0
# LCLAS_NM               0
# ZIP_NO                 1
# FCLTY_ROAD_NM_ADDR     0
# lat                    0
# lon                    0
# OPTN_DC               55
# ADIT_DC                0
# AREA                   0
# dtype: int64

# %%
df = df.fillna('-')

# %%
df.isna().sum()
# Out:
# FCLTY_NM              0
# LCLAS_NM              0
# ZIP_NO                0
# FCLTY_ROAD_NM_ADDR    0
# lat                   0
# lon                   0
# OPTN_DC               0
# ADIT_DC               0
# AREA                  0
# dtype: int64

# %%
df['FCLTY_NM'].nunique()
# Out:
# 1028

# %%
# 카페명 검색

# %%
df.loc[ df['FCLTY_NM'].str.contains('북카페') ]
# Out:
#             FCLTY_NM LCLAS_NM   ZIP_NO  \
# 0            강릉야행북카페      북카페  25528.0
# 1         북카페 봄날에 연애      북카페  26417.0
# 2         북카페 책 있는 숲      북카페  26021.0
# 3             북카페 뜨락      북카페  24114.0
# 11            북카페 모모       카페  25532.0
# ...              ...      ...      ...
# 993   북카페 심심푸리 보령동대점      북카페  33433.0
# 994              북카페      북카페  33115.0
# 1000         북적북적북카페      북카페  33624.0
# 1018          도깨비북카페      북카페  32143.0
# 1044          술딴스북카페      북카페  10859.0
#
#                             FCLTY_ROAD_NM_ADDR        lat         lon  \
# 0                  강원 강릉시 임영로155번길 6 1층 45,47호  37.755074  128.890851
# 1                               강원 원주시 옛시청길 20  37.352672  127.944585
# 2                           강원 태백시 황지로 28 / 3층  37.161343  128.990795
# 3                           강원 화천군 화천읍 산천어길 79  38.108783  127.711564
# 11                      강원도 강릉시 토성로 180 모모의 외출  37.756724  128.895760
# ...

# %%
my_Search = df.loc[ df['FCLTY_NM'].str.contains('북카페') ]

# %%
my_Search.iloc[: ,[8,0,1,3,6,7]]
# Out:
#      AREA        FCLTY_NM LCLAS_NM                        FCLTY_ROAD_NM_ADDR  \
# 0      강원         강릉야행북카페      북카페               강원 강릉시 임영로155번길 6 1층 45,47호
# 1      강원      북카페 봄날에 연애      북카페                            강원 원주시 옛시청길 20
# 2      강원      북카페 책 있는 숲      북카페                        강원 태백시 황지로 28 / 3층
# 3      강원          북카페 뜨락      북카페                        강원 화천군 화천읍 산천어길 79
# 11     강원          북카페 모모       카페                    강원도 강릉시 토성로 180 모모의 외출
# ...   ...             ...      ...                                       ...
# 993    충청  북카페 심심푸리 보령동대점      북카페                        충청남도 보령시 한내로 43 3층
# 994    충청             북카페      북카페  충청남도 부여군 규암면 백제문로 367 한국전통문화대학교 학술정보관 2층
# 1000   충청         북적북적북카페      북카페                  충청남도 서천군 한산면 한산모시길 42 2층
# 1018   충청          도깨비북카페      북카페                       충청남도 태안군 태안읍 동문3길 3
# 1044   경기          술딴스북카페      북카페         경기도 파주시 탄현면 헤이리마을길 21-7 더 장미건물 1층
#
# ...

# %%
# 지역 검색

# %%
AREA_df = df['AREA'].value_counts().to_frame().reset_index()

# %%
AREA_df['index'].to_list()
# Out:
# ['서울',
#  '경기',
#  '대구',
#  '부산',
#  '인천',
#  '강원',
#  '충청',
#  '제주',
#  '광주',
#  '대전',
#  '경상',
#  '울산',
#  '전라',
#  '세종',
#  '전북',
#  '전남']

# %%
df.loc[ df['AREA'] == '강원' ]
# Out:
#        FCLTY_NM LCLAS_NM   ZIP_NO                   FCLTY_ROAD_NM_ADDR  \
# 0       강릉야행북카페      북카페  25528.0          강원 강릉시 임영로155번길 6 1층 45,47호
# 1    북카페 봄날에 연애      북카페  26417.0                       강원 원주시 옛시청길 20
# 2    북카페 책 있는 숲      북카페  26021.0                   강원 태백시 황지로 28 / 3층
# 3        북카페 뜨락      북카페  24114.0                   강원 화천군 화천읍 산천어길 79
# 4        한낮의 바다     독립서점  25505.0  강원도 강릉시 강릉대로159번안길 12 1층, 서점 한낮의 바다
# 5          안목책방      북카페  25560.0                강원도 강릉시 경강로 2581 1층1호
# 6         명주사랑채      북카페  25538.0                 강원도 강릉시 경강로2046번길 11
# 7          북스북스      북카페  25510.0               강원도 강릉시 솔올로 66 문화빌딩 2층
# 8         카페에세이      북카페  25429.0       강원도 강릉시 연곡면 영진길 33 ES프라우드 101호
# 9          고래책방     일반서점  25551.0                     강원도 강릉시 율곡로 2848
# 10          책다방      북카페  25516.0                     강원도 강릉시 정원로 78-9
# 11       북카페 모모       카페  25532.0               강원도 강릉시 토성로 180 모모의 외출
# ...

# %%
# 소개 검색

# %%
df.loc[ df['OPTN_DC'].str.contains('고양이') ]
# Out:
#       FCLTY_NM LCLAS_NM   ZIP_NO                    FCLTY_ROAD_NM_ADDR  \
# 80       이야기마을     독립서점  10298.0             경기도 고양시 덕양구 원당로113번길 48-7
# 98    북앤빅뱅 광명점      만화방  14217.0                       경기도 광명시 오리로 936
# 108   북앤빅뱅 산본점      만화방  15865.0             경기도 군포시 산본로323번길 16-30 7층
# 182   북앤빅뱅 수지점      만화방  16837.0  경기도 용인시 수지구 풍덕천로 127 지하층(풍덕천동,수지프라자)
# 197        냥이툰      북카페  12913.0               경기도 하남시 미사강변동로 127 805호
# 299       심플책방     독립서점  41244.0               대구광역시 동구 동부로34길 4 지하 1층
# 543    꿈꾸는 타자기      북카페   1205.0                   서울특별시 강북구 솔샘로68길 16
# 563        고지트      북카페   8813.0                  서울특별시 관악구 신림로 107 2층
# 743     새벽감성1집     독립서점   7903.0            서울특별시 양천구 월정로50길 16-8 101호
# 905      고양이책방      북카페  22376.0                  인천광역시 중구 모랫말로 6-3 1층
# 1011  고양이책방분홍코     일반서점  31129.0             충청남도 천안시 동남구 은행길 5-5 / 2층
#
#             lat         lon                                       OPTN_DC  \
# ...

# %%
df.loc[ df['OPTN_DC'].str.contains('맥주') ]
# Out:
#         FCLTY_NM LCLAS_NM   ZIP_NO           FCLTY_ROAD_NM_ADDR        lat  \
# 23      인디문학 1호점     일반서점  26237.0           강원도 영월군 영월읍 하송로 97  37.179637
# 84      미스터버티고책방     일반서점  10450.0          경기도 고양시 일산동구 강송로 33  37.641510
# 186        모어댄북스      북카페  16015.0              경기도 의왕시 내손동 123  37.370702
# 218          까치밥     일반서점  52219.0       경상남도 산청군 산청읍 덕계로 13-14  35.415829
# 339         봉산19     독립서점  41958.0         대구광역시 중구 봉산문화길 19 2층  35.860960
# 362         이츠타임      북카페  35240.0   대전광역시 서구 둔산로 129 메디빌딩 B102  36.351584
# 412       북살롱 부산     일반서점  47816.0        부산광역시 동래구 온천천로 197 3층  35.201819
# 623        로뎀나무밑      북카페   4087.0            서울특별시 마포구 독막로 176  37.535658
# 650  에디토리얼카페비플러스      북카페   4043.0    서울특별시 마포구 양화로12길 16-12 찬홍  37.545656
# 659    만화살롱 유어마나      북카페   4049.0         서울특별시 마포구 와우산로 13 B1  37.552063
# 661   gaga77page     일반서점   4049.0      서울특별시 마포구 와우산로15길 50 2층  37.548734
# ...

# %%
# 주소 검색

# %%
df.loc[ df['FCLTY_ROAD_NM_ADDR'].str.contains('하송로 97') ]
# Out:
#     FCLTY_NM LCLAS_NM   ZIP_NO  FCLTY_ROAD_NM_ADDR        lat         lon  \
# 23  인디문학 1호점     일반서점  26237.0  강원도 영월군 영월읍 하송로 97  37.179637  128.460944
#
#                          OPTN_DC  ADIT_DC AREA
# 23  문학전문, 독립출판물, 동네책방, 커피, 차, 맥주  카페 : 있음   강원

# %%
# 카페명, 소개, 주소 검색 지역검색은 따로 빼서 검색할 수 있게함
# 지역 검색시 지도 자동 표시

# %%
map_df = df[['lat', 'lon', 'AREA']]

# %%
map_df.loc[map_df['AREA'] == '강원' ]
# Out:
#           lat         lon AREA
# 0   37.755074  128.890851   강원
# 1   37.352672  127.944585   강원
# 2   37.161343  128.990795   강원
# 3   38.108783  127.711564   강원
# 4   37.757721  128.889088   강원
# 5   37.773738  128.941721   강원
# 6   37.750874  128.893148   강원
# 7   37.767780  128.878981   강원
# 8   37.871263  128.839942   강원
# 9   37.758235  128.897215   강원
# 10  37.763501  128.873199   강원
# 11  37.756724  128.895760   강원
# 12  37.521671  129.113609   강원
# 13  37.591239  129.089407   강원
# 14  37.481769  129.126165   강원
# 15  37.487578  129.103022   강원
# 16  37.233767  129.042363   강원
# 17  37.442772  129.164186   강원
# 18  38.198648  128.535110   강원
# 19  38.191090  128.579272   강원
# 20  38.211365  128.589367   강원
# 21  38.210547  128.591082   강원
# 22  38.203184  128.590219   강원
# 23  37.179637  128.460944   강원
# 24  37.337504  128.008346   강원
# 25  37.354712  127.942084   강원
# 26  37.334365  127.929950   강원
# 27  37.318209  127.963981   강원
# 28  37.366790  128.004120   강원
# ...

# %%
# 해당 지역에 위치한 카페 갯수

# %%
df.groupby('AREA')['AREA'].count()
# Out:
# AREA
# 강원     58
# 경기    170
# 경상     34
# 광주     40
# 대구     68
# 대전     38
# 부산     65
# 서울    366
# 세종      3
# 울산     29
# 인천     65
# 전남      1
# 전라     13
# 전북      3
# 제주     50
# 충청     53
# Name: AREA, dtype: int64

# %%
# 데이터가 적은 전남과 세종, 전북은 삭제하겠다

# %%
df.loc[ df['AREA'] == '세종']
# Out:
#      FCLTY_NM LCLAS_NM   ZIP_NO          FCLTY_ROAD_NM_ADDR        lat  \
# 813      꾸메문고     일반서점  30147.0       세종특별자치시 국책연구원3로 12 4층  36.492374
# 814      소담서점     일반서점  30151.0  세종특별자치시 한누리대로 2016 4층 407호  36.485016
# 1051      카페북      북카페  30121.0             세종특별자치시 갈매로 353  36.495609
#
#              lon               OPTN_DC  \
# 813   127.303255     도서, 문구, 하비팩토리, 카페
# 814   127.299630  동네 커피 파는 서점, 책 파는 카페
# 1051  127.262433           다양한 국내도서 취급
#
#                                                 ADIT_DC AREA
# 813          주차 : 가능, 화장실 남녀구분 : 구분, 카페 : 있음, 리뷰여부 : 있음   세종
# 814   주차 : 가능, 화장실 남녀구분 : 구분, 카페 : 있음, 헌책방 : 있음, 리뷰여...   세종
# 1051                        주차 : 가능, 카페 : 있음, 리뷰여부 : 있음   세종

# %%
df = df.drop([813, 814, 1051], axis= 0 )

# %%
df.loc[ df['AREA'] == '전남']
# Out:
#        FCLTY_NM LCLAS_NM   ZIP_NO FCLTY_ROAD_NM_ADDR        lat         lon  \
# 909  북카페심심푸리목포점      북카페  58691.0    전남 목포시 신흥로 38-1  34.802726  126.425171
#
#                                  OPTN_DC                 ADIT_DC AREA
# 909  만화카페, 가족전체가 함께 즐길 수 있는 노링공간, 데이트 코스  화장실 남녀구분 : 구분, 카페 : 있음   전남

# %%
df = df.drop(909, axis= 0 )

# %%
df.loc[ df['AREA'] == '전북']
# Out:
#     FCLTY_NM LCLAS_NM   ZIP_NO             FCLTY_ROAD_NM_ADDR        lat  \
# 923    엘 북카페      북카페  54542.0  전북 익산시 고봉로36길 10-1 드림오피스텔B 2층  35.962971
# 924    청동북카페      북카페  54956.0        전북 전주시 완산구 세내로 504-7 1층  35.832578
# 925   북카페아르고      북카페  54954.0             전북 전주시 완산구 유연로 313  35.825486
#
#             lon                                      OPTN_DC  \
# 923  126.972479                               조용하고 아기자기한 분위기
# 924  127.103793                       독서 활동 장소, 많은 종류의 책과 음식
# 925  127.119821  아늑한 분위기와 홈메이드 메뉴, 책도 판매하고 스터디도 할 수 있는 공간 마련
#
#                              ADIT_DC AREA
# 923  주차 : 가능, 화장실 남녀구분 : 구분, 카페 : 있음   전북
# 924                          카페 : 있음   전북
# 925                          카페 : 있음   전북

# %%
df = df.drop([923, 924, 925], axis= 0 )

# %%
df.groupby('AREA')['AREA'].count()
# Out:
# AREA
# 강원     58
# 경기    170
# 경상     34
# 광주     40
# 대구     68
# 대전     38
# 부산     65
# 서울    366
# 울산     29
# 인천     65
# 전라     13
# 제주     50
# 충청     53
# Name: AREA, dtype: int64

# %%
df.to_csv('bookcafe_stor.csv')
